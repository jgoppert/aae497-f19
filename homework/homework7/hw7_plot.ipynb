# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = open('resolution.txt', 'r')
lines = data.readlines

numbers = [[i for i in line.split()] for line in data.readlines()]

print(numbers)
time=[]
res=[]

for j in numbers:
    time.append(float(j[0]))
    res.append(float(j[1]))
# Out:
# [['26022', '0.001'], ['22298', '0.1'], ['23024', '1'], ['17772', '10']]

# %%
plt.plot(res, time)
plt.xlabel('Resolution [m]')
plt.ylabel('Time [ns]')
plt.title('Calculation Time vs Resolution')
plt.show()
