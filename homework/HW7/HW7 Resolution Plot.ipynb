# %%
import control
import casadi as ca
import numpy as np
import matplotlib.pyplot as plt

# %%
resolution = [0.1,1,10,50,100]

time = [16260,15423,15371,16625,16256]
plt.scatter(resolution,time)
plt.xlabel('resolution, m')
plt.ylabel('Simulation Time, ns')
plt.grid()
plt.title('Simulation Resolution vs. Computational Time')
# Out:
# Text(0.5, 1.0, 'Simulation Resolution vs. Computational Time')
